# %%
import numpy as np
import pandas as pd

# %%
country=['India','Pakistan','USA','Nepal' ,'Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
marks=[67,57,89,100]
subjects=['maths','english','science','hindi']
pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks=pd.Series(marks,index=subjects,name='anubhav ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: anubhav ke marks, dtype: int64

# %%
marks={'maths':99,'english':95,'science':92}
marks_series=pd.Series(marks,name='Anubhav ke marks')
marks_series
# Out:
# maths      99
# english    95
# science    92
# Name: Anubhav ke marks, dtype: int64

# %%
marks_series.size
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.size
# Out:
# 3

# %%
marks_series.is_unique
# Out:
# True

# %%
marks_series.name
# Out:
# 'Anubhav ke marks'

# %%
marks_series.index
# Out:
# Index(['maths', 'english', 'science'], dtype='object')

# %%
marks_series.keys
# Out:
# <bound method Series.keys of maths      99
# english    95
# science    92
# Name: Anubhav ke marks, dtype: int64>

# %%
subs=pd.read_csv('/content/subs.csv')
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.index
# Out:
# RangeIndex(start=0, stop=365, step=1)

# %%
subs=pd.Series()
# Out:
# <ipython-input-22-bf332ef04796>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   subs=pd.Series()

# %%
subs.dtype
# Out:
# dtype('float64')

# %%
subs.index
# Out:
# Index([], dtype='object')

# %%
bolly=pd.read_csv('/content/bollywood.csv',squeeze=True)
bolly
# Out:
# <ipython-input-26-695f6db7d775>:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   bolly=pd.read_csv('/content/bollywood.csv',squeeze=True)
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# ...

# %%
bolly.sample(5)
# Out:
#                       movie                 lead
# 582             Kai Po Che!        Rajkummar Rao
# 215  Babumoshai Bandookbaaz  Nawazuddin Siddiqui
# 158                  Simmba        Ranveer Singh
# 623          Love in Bombay        Joy Mukherjee
# 740   Mumbai Mast Kallander               Mohsin

# %%
bolly.value_counts()
# Out:
# movie                     lead
# Andaaz                    Akshay Kumar        2
# Tanu Weds Manu: Returns   Kangana Ranaut      2
# Gabbar Is Back            Akshay Kumar        2
# 1920 (film)               Rajniesh Duggall    1
# Newton (film)             Rajkummar Rao       1
#                                              ..
# Ghayal: Once Again        Sunny Deol          1
# Ghanchakkar (film)        Vidya Balan         1
# Ghajini (2008 film)       Aamir Khan          1
# Genius (2018 Hindi film)  Utkarsh Sharma      1
# Zor Lagaa Ke...Haiya!     Meghan Jadhav       1
# Length: 1497, dtype: int64

# %%
subs.sort_values(ascending=False).head(1).values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-9d2ec6032c79> in <cell line: 1>()
# ----> 1 subs.sort_values(ascending=False).head(1).values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
subs.mean()
print(subs.std())
# Out:
# nan

# %%
bolly[5:16]
# Out:
#                                movie                  lead
# 5                        Soni (film)  Geetika Vidya Ohlyan
# 6                      Fraud Saiyaan          Arshad Warsi
# 7                         Bombairiya          Radhika Apte
# 8   Manikarnika: The Queen of Jhansi        Kangana Ranaut
# 9                   Thackeray (film)   Nawazuddin Siddiqui
# 10                            Amavas             Ali Asgar
# 11                         Gully Boy         Ranveer Singh
# 12                         Hum Chaar           Prit Kamani
# 13                     Total Dhamaal            Ajay Devgn
# 14                        Sonchiriya  Sushant Singh Rajput
# 15                 Badla (2019 film)      Amitabh Bachchan
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# ...

# %%
bolly.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: >

# %%
import sys
sys.getsizeof(subs)
# Out:
# 124
